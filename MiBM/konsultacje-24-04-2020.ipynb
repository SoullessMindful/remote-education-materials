# %% [markdown]
# <style>
#   p {
#     font-size: 30px;
#   }
#
#   p:hover {
#     color: hsl(180, 100%, 60%);
#   }
#
#   h1 {
#     font-size: 60px;
#     color: hsl(210, 100%, 50%);
#     background-color: hsl(0, 0%, 20%);
#     padding: 10px;
#   }
#
#   h2 {
#     font-size: 50px;
#     color: hsl(270, 100%, 50%);
#     background-color: hsl(0, 0%, 20%);
#     padding: 10px;
#   }
#
#   h3 {
#     font-size: 40px;
#     color: hsl(60, 100%, 50%);
#     background-color: hsl(0, 0%, 20%);
#     padding: 10px;
#   }
# </style>
#
#
# # Konsultacje
# ## RMT MiBM rok: 1, stopień: 1
# ### 24.04.2020

# %% [markdown]
# **Zad** Napisać równanie płaszczyzny przechodzącej przez punkt $A = (-2, 1, -3)$
#
# i prostą
# $\left\{
#     \begin{array}
#         & x-y+1 & = & 0\\
#           x + 2y - z +8 & = & 0\\
#     \end{array}
# \right.$
#
# Wstawiamy do pierwszego równania:
#
# $
#     (-2) - 1 + 1 = -2 \not= 0
# $
#
# Wstawiamy d drugiego równania:
#
# $
#     (-2) + 2\cdot 1 - (-3) + 8 = 11 \not= 0
# $
#
# Postać ogólna równania płaszczyzny:
#
# $
#     \alpha\cdot x + \beta\cdot y + \gamma\cdot z = \delta
# $
#
# Wektor normalny do płaszczyzny
# $
#     \mathbf{n} = [ \alpha, \beta, \gamma ]
# $
#
# Zamieniamy prostą na postać parametryczną:
#
# $
#     \begin{bmatrix}
#         1 & -1 & 0 & | & -1\\
#         1 & 2 & -1 & | & -8
#     \end{bmatrix}
# $
# $
#     \overset{w_2 - w_1}{\rightarrow}
# $
# $
#     \begin{bmatrix}
#         1 & -1 & 0 & | & -1\\
#         0 & 3 & -1 & | & -7
#     \end{bmatrix}
# $
# $
#     \overset{w_1 + \frac{1}{3}w_2}{\rightarrow}
# $
# $
#     \begin{bmatrix}
#         1 & 0 & -\frac{1}{3} & | & -\frac{10}{3}\\
#         0 & 3 & -1 & | & -7
#     \end{bmatrix}
# $
#
# $\left\{
#     \begin{array}
#         & x & = & \frac{t}{3} - \frac{10}{3}\\
#           y & = & \frac{t}{3} -\frac{7}{3}\\
#           z & = & t\\
#     \end{array}
# \right.$
# dla $t \in \mathbb{R}$
#
# Wektor kierunkowy prostej: $[\frac{1}{3}, \frac{1}{3}, 1]$
#
# Również wektor kierunkowy prostej $\mathbf{v} = 3 \cdot [\frac{1}{3}, \frac{1}{3}, 1] = [1, 1, 3]$
#
# Podstawiamy $t = 7$:
#
# $B = (\frac{7}{3} - \frac{10}{3}, \frac{7}{3} - \frac{7}{3}, 7) = (-1, 0, 7)$
#
# $\mathbf{n} \perp \mathbf{v}$
#
# $\mathbf{w} = \overrightarrow{AB} = [-1 - (-2), 0 - 1, 7 - (-3)] = [1, -1, 10]$
#
# $\mathbf{n} \perp \mathbf{w}$
#
# Zatem:
#
# $\mathbf{n} = \mathbf{v} \times \mathbf{w} =$
# $
# \begin{vmatrix}
#     \hat{i} & \hat{j} & \hat{k}\\
#     1 & 1 & 3\\
#     1 & -1 & 10
# \end{vmatrix}
# $
# $=\hat{i} \begin{vmatrix} 1 & 3\\ -1 & 10\end{vmatrix} - \hat{j} \begin{vmatrix} 1 & 3\\ 1 & 10\end{vmatrix} + \hat{k} \begin{vmatrix} 1 & 1\\ 1 & -1\end{vmatrix}$
# $= 13\hat{i} - 7\hat{j} - 2\hat{k} = [13, -7, -2]$
#
# Wstawiamy do ogólnego równania płaszczyzny:
#
# $
#     13\cdot (-1) - 7 \cdot 0 - 2\cdot 7 = \delta
# $
#
# Stąd $\delta = -27$.
#
# **Odp** Równanie szukanej płaszczyzny to
# $
#     13x - 7y - 2z = -27.
# $
#
# $((( 13x - 7y - 2z + 27 = 0 )))$
#
# **Uwaga**
#
# Jest jeszcze trzecia postać prostej w przestrzeni trojwymiarowej.
#
# $\left\{
#     \begin{array}
#         & x & = & \frac{t}{3} - \frac{10}{3}\\
#           y & = & \frac{t}{3} -\frac{7}{3}\\
#           z & = & t\\
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & 3x & = & t - 10\\
#           3y & = & t - 7\\
#           z & = & t\\
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & 3x + 10 & = & t\\
#           3y + 7 & = & t\\
#           z & = & t\\
#     \end{array}
# \right.$
#
# Postać kanoniczna:
#
# $3x + 10 = 3y + 7 = z$
#
# $\frac{x - \frac{-10}{3}}{1} = \frac{y - \frac{-7}{3}}{1} = \frac{z - 0}{3} $
#
# Wektor kierunkowy $[1, 1, 3]$.
#
# Pewien punkt na prostej $(\frac{-10}{3}, \frac{-7}{3}, 0)$

# %% [markdown]
# **Zad** Niech $P = (1, -1, 4)$ i $L\colon \frac{x+3}{2} = \frac{y+2}{2} = \frac{z-8}{-2}$. Obliczyć odległość $P$ od $L$.
#
# $\frac{1+3}{2} \not= \frac{-1+2}{2} \not= \frac{4-8}{-2}$
#
# $2 \not= \frac{1}{2} \not= 2$
#
# $\mathbf{u} = [2, 2, -2]$
#
# Płaszczyzna prostopadła do $L$ i przechodząca przez $P$:
#
# $
#     2x + 2y - 2z = \delta
# $
#
# $
#     2\cdot 1 + 2\cdot (-1) - 2\cdot 4 = \delta
# $
#
# $
#     \delta = -8
# $
#
# $\pi\colon$
# $
#     2x + 2y - 2z = -8
# $
#
# Znajdujemy punkt przecięcia $L$ z $\pi$:
#
# $\left\{
#     \begin{array}
#         & 2x + 2y - 2z & = & -8\\
#           x+3 & = & y+2\\
#           y+2 & = & -z + 8\\
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & 2x + 2y - 2z & = & -8\\
#           x - y & = &-1\\
#           y+z & = &6\\
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & 2x + 4y & = & 4\\
#           x - y & = &-1\\
#           y+z & = &6\\
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & x & = & 0\\
#           x - y & = &-1\\
#           y+z & = &6\\
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & x & = & 0\\
#           y & = &1\\
#           z & = &5\\
#     \end{array}
# \right.$
#
# Rzut punktu $P$ na prostą $L$: $P' = (0, 1, 5)$.
#
# $\| \overrightarrow{PP'} \| = \| [0 - 1, 1 - (-1), 5 - 4] \| = \| [-1, 2, 1] \| = \sqrt{(-1)^2 + 2^2 + 1^1} = \sqrt{6}$
#
# **Odp** Szukana odległość to $\sqrt{6}$.
#
# **Uwaga** Punkt symetryczny do $P$ względem $L$: $P''$
#
# $\frac{1}{2}(P + P'') = P'$
#
# $\mathbf{v} = \overrightarrow{PP'} = [-1, 2, 1]$
#
# $P'' = P' + \mathbf{v} = (0-1,1+2,5+1) = (-1, 3, 6)$

# %% [markdown]
# $\| \perp \parallel \hat{i} [ \{ \cdot \circ \times \forall \exists$
