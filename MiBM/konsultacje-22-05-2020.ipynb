# %% [markdown]
# <style>
#   p {
#     font-size: 30px;
#   }
#
#   p:hover {
#     color: hsl(180, 100%, 60%);
#   }
#
#   h1 {
#     font-size: 60px;
#     color: hsl(210, 100%, 50%);
#     background-color: hsl(0, 0%, 20%);
#     padding: 10px;
#   }
#
#   h2 {
#     font-size: 50px;
#     color: hsl(270, 100%, 50%);
#     background-color: hsl(0, 0%, 20%);
#     padding: 10px;
#   }
#
#   h3 {
#     font-size: 40px;
#     color: hsl(60, 100%, 50%);
#     background-color: hsl(0, 0%, 20%);
#     padding: 10px;
#   }
# </style>
#
#
# # Konsultacje
# ## RMT MiBM rok: 1, stopień: 1
# ### 22.05.2020

# %% [markdown]
# **Zad** Znaleźć ekstrema lokalne funkcji danej wzorem $f(x,y)=x^3+y^3-3xy+17$.
#
# $D_f = \mathbb{R}^2$
#
# $\frac{\partial f}{\partial x} = 3x^2 - 3y = 0$
#
# $\frac{\partial f}{\partial y} = 3y^2 - 3x = 0$
#
# $\left\{
#     \begin{array}
#         & 3x^2 - 3y & = & 0\\
#           3y^2 - 3x & = & 0
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & x^2 - y & = & 0\\
#           y^2 - x & = & 0
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & x^2 & = & y\\
#           y^2 - x & = & 0
#     \end{array}
# \right.$
#
# $x^4 - x = 0$
#
# $x(x^3 - 1)$
#
# $(x = 0 \wedge y = 0) \vee (x = 1 \wedge y = 1)$
#
# $P = (0, 0)$ PPOE
#
# $R = (1, 1)$ PPOE
#
# $\frac{\partial^2 f}{\partial x^2} = 6x$
#
# $\frac{\partial^2 f}{\partial y^2} = 6y$
#
# $\frac{\partial^2 f}{\partial y \partial x} = -3$
#
# $\frac{\partial^2 f}{\partial x \partial y} = -3$
#
# $H =
#     \begin{vmatrix}
#         6x & -3\\
#         -3 & 6y
#     \end{vmatrix}
# $
#
# $H|_P =
#     \begin{vmatrix}
#         0 & -3\\
#         -3 & 0
#     \end{vmatrix}
#     = 0 - 9 = -9 < 0
# $
#
# W punkcie $P$ nie ma ekstremum lokalnego (punkt siodłowy)
#
# $H|_R =
#     \begin{vmatrix}
#         6 & -3\\
#         -3 & 6
#     \end{vmatrix}
#     = 36 - 9 = 27 > 0
# $
#
# W punkcie $R$ mamy ekstremum lokalne.
#
# $\frac{\partial^2 f}{\partial x^2}|_R = 6 > 0$, więc w $R$ mamy minimum lokalnie.
#
# $f(R) = 16$
#
# **Odp** Funkcja $f$ przyjmuje w punkcie $(1, 1)$ minimum lokalne równe $16$.

# %% [markdown]
# $f\colon (x, y, z) \to f(x, y, z)$
#
# $Q \in D_f$
#
# $\frac{\partial f}{\partial x}|_Q = \frac{\partial f}{\partial y}|_Q = \frac{\partial f}{\partial z}|_Q = 0$
#
# $\frac{\partial^2 f}{\partial x^2}|_Q = 2$
#
# $\frac{\partial^2 f}{\partial y^2}|_Q = 1$
#
# $\frac{\partial^2 f}{\partial z^2}|_Q = -1$
#
# $\frac{\partial^2 f}{\partial y \partial x}|_Q = -1$
#
# $\frac{\partial^2 f}{\partial z \partial x}|_Q = 4$
#
# $\frac{\partial^2 f}{\partial y \partial z}|_Q = 0$
#
# $
#     \begin{bmatrix}
#         2 & -1 & 4 \\
#         -1  & 1 & 0 \\
#          4 & 0 & -1 \\
#     \end{bmatrix}
# $
#
# $
#     \begin{vmatrix}
#         2
#     \end{vmatrix}
#     = 2 > 0
# $ (szansa na minimum)
#
# $
#     \begin{vmatrix}
#         2 & -1\\
#         -1  & 1\\
#     \end{vmatrix}
#     = 2 - 1 = 1 > 0
# $ (szansa na ekstremum)
#
# $
#     \begin{vmatrix}
#         2 & -1 & 4 \\
#         -1  & 1 & 0 \\
#          4 & 0 & -1 \\
#     \end{vmatrix}
#     = -17 < 0
# $ (szansa na maksimum)
#
# W tym wypadku nie ma ekstremum, ponieważ mamy zarówno szansę na minimum, jak i na maksimum.
#
# MINIMUM: +, +, +, +, +, +, ...
#
# MAKSIMUM: -, +, -, +, -, +, ...

# %% [markdown]
# $f(x, y, z) = \cos(x + y) z + x - y^2$
#
# $\frac{\partial f(x, y, z)}{\partial x} = (\cos(x + y) z + x - y^2)'_x = -\sin(x+y)z + 1$
#
# $\frac{\partial f(x, y, z)}{\partial z} = \frac{\partial}{\partial z} (\cos(x + y) z + x - y^2) = (\cos(x + y) z + x - y^2)'_z = \cos(x + y)$
#
# $\frac{\partial^2 f}{\partial x \partial y} = \frac{\partial}{\partial x} \frac{\partial f}{\partial y}$

# %% [markdown]
# **Zad** Znaleźć ekstrema lokalne funkcji danej wzorem $f(x, y) = 2xy + \frac{1}{x} + \frac{4}{y}$
#
# $x \not= 0$, $y \not= 0$
#
# $D_f = \{ (x, y) \in \mathbb{R}^2 \colon x \not= 0, y \not= 0 \}$
#
# $\frac{\partial f}{\partial x} = 2y - \frac{1}{x^2} = 0$
#
# $\frac{\partial f}{\partial y} = 2x - \frac{4}{y^2} = 0$
#
# $\left\{
#     \begin{array}
#         & 2y - \frac{1}{x^2} & = & 0\\
#           2x - \frac{4}{y^2} & = & 0
#     \end{array}
# \right.$
#
# $\left\{
#     \begin{array}
#         & 2y & = & \frac{1}{x^2}\\
#           2x & = & \frac{4}{y^2}
#     \end{array}
# \right.$
#
# $x = \frac{2}{y^2}$
#
# $2y = \frac{1}{(\frac{2}{y^2})^2}$
#
# $2y = \frac{y^4}{4}$
#
# $8y = y^4$
#
# $y(y^3 - 8) = 0$
#
# $(x = 0 \wedge y = 0) \vee (x = \frac{1}{2} \wedge y = 2)$
#
# $(0, 0)$ POZA DZIEDZINĄ
#
# $D = (\frac{1}{2}, 2)$ PPOE
#
# $\frac{\partial^2 f}{\partial x^2} = \frac{2}{x^3}$
#
# $\frac{\partial^2 f}{\partial y^2} = \frac{8}{y^3}$
#
# $\frac{\partial^2 f}{\partial y \partial x} = 2$
#
# $H|_D =
#     \begin{vmatrix}
#         16 & 2\\
#         2 & 1
#     \end{vmatrix}
#     = 16 - 4 = 12 > 0
# $ (mamy ekstremum lokalne)
#
# $16 > 0$ ($1 > 0$) (minimum lokalne)
#
# $f(D) = 2 + 2 + 2 = 6$
#
# **Odp** Funkcja $f$ przyjmuje w punkcie $(\frac{1}{2}, 2)$ *minimum lokalne* równe $6$.

# %%
import numpy as np

a = np.array([
    [2, -1, 4],
    [-1, 1, 0],
    [4, 0, -1]
])

print(np.linalg.det(a))
# Out:
# -17.0

# %% [markdown]
# $\| \perp \parallel \hat{i} [ \{ \cdot \circ \times \forall \exists$

# %%
from matplotlib import pyplot as plt
import numpy as np

X = np.linspace(-2, 2, 101)

Y1 = X*X -1
Y2 = 2*X

plt.plot(X, Y1, 'b')
plt.plot(X, Y2, 'g')
plt.show()
